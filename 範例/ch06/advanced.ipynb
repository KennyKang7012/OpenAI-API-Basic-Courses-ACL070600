# %%
# !pip install googlesearch-python
from googlesearch import search

# %%
query = '2024年 台灣選舉, 誰當選總統?'
for item in search(query, num_results=4, advanced=True, lang='zh-TW'):
  print(f'標題：{item.title}')
  print(f'描述：{item.description}')
  print(f'連結：{item.url}')
  print()
