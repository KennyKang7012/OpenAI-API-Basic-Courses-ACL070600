# %%
animal = ['忠狗','花貓','長頸鹿','老虎','獅子']  # 建立animal字串串列
my_iter = iter(animal)                # my_iter為迭代器
print(next(my_iter))                  # 第一次迭代,傳出'忠狗'字串
print(next(my_iter))                  # 第二次迭代傳出'花貓'字串
print(next(my_iter))                  # 第三次迭代傳出'長頸鹿'字串
