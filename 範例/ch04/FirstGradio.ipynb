# %%
# !pip install gradio

# %%
import gradio as gr

# %%
def hello(user_name):
  return user_name + '你好！'

# %%
iface=gr.Interface(
    fn=hello,
    inputs='text',
    outputs='text')
"""gr.Interface(
    fn=hello,
    inputs='text',
    outputs='text').queue().launch()"""

# %%
iface.queue()
iface.launch()
